# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import csv
import pandas as pd
from pathlib import Path
import math

# %% [markdown]
# # Load Trace Data

# %%
base_dirs = [
    "isw_and", "isw_and_v1", "isw_and_v2"
]

# Load all trace data
trace_data_HW = [
    np.load(f"{base_dir}/traces_isw_and/simulated_HW/isw_and_traces.npy")
    for base_dir in base_dirs
]

trace_data_HD = [
    np.load(f"{base_dir}/traces_isw_and/simulated_HD/isw_and_traces.npy")
    for base_dir in base_dirs
]

# Get number of traces and number of samples for each version
number_traces_HW = [traces.shape[0] for traces in trace_data_HW]
number_samples_HW = [traces.shape[1] for traces in trace_data_HW]

number_traces_HD = [traces.shape[0] for traces in trace_data_HD]
number_samples_HD = [traces.shape[1] for traces in trace_data_HD]

# Print summary
print("Number of HW traces for isw_and v0-v2:", *number_traces_HW)
print("Number of HW samples for isw_and v0-v2:", *number_samples_HW)

print("Number of HD traces for isw_and v0-v2:", *number_traces_HD)
print("Number of HD samples for isw_and v0-v2:", *number_samples_HD)
# Out:
# Number of HW traces for isw_and v0-v2: 100 100 100
# Number of HW samples for isw_and v0-v2: 16 22 15
# Number of HD traces for isw_and v0-v2: 100 100 100
# Number of HD samples for isw_and v0-v2: 15 21 14

# %% [markdown]
# # Plot Traces

# %%
# Plot one trace (trace 0) from each dataset
fig = plt.figure(figsize=(30, 6))
plt.tight_layout()

font = {'weight': 'normal', 'size': 18}
plt.xlabel('Instruction Sequence', fontdict=font)
plt.ylabel('Simulated Power Consumption', fontdict=font)
plt.yticks(fontsize=14)

colors = ['blue', 'green', 'red']

# Plot each trace
for i, traces in enumerate(trace_data_HW):
    trace = traces[0]  # Take the first trace
    instruction_index = list(range(len(trace)))  # Generate correct X axis
    plt.plot(instruction_index, trace, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])

plt.grid(True)
plt.legend(loc='lower right', fontsize=14)
plt.title('Comparison of Simulated HW Traces (Trace 0) for isw_and v0-v2', fontdict=font)
plt.savefig('figures/trace_HW_compare_all_versions_isw_and_v1.pdf', bbox_inches='tight')
plt.show()

# %%
num_versions = len(trace_data_HW)
cols = math.ceil(num_versions / 2)  # Adjust this if you want 3 or 4 per row
rows = 2 if num_versions > 1 else 1

fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows), sharey=True)

# Flatten axes array
axes = axes.flatten() if num_versions > 1 else [axes]

font = {'weight': 'normal', 'size': 16}
colors = ['blue', 'green', 'red']

for i, (traces, ax) in enumerate(zip(trace_data_HW, axes)):
    trace = traces[0]  # Take the first trace
    instruction_index = list(range(len(trace)))  # X-axis
    ax.plot(instruction_index, trace, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])
    ax.set_title(f'isw_and v{i}', fontsize=16)
    ax.set_xlabel('Instruction Sequence', fontsize=14)
    ax.grid(True)
    ax.legend(fontsize=12)

# Set y-label only for the leftmost plots
for i in range(0, len(axes), cols):
    axes[i].set_ylabel('Simulated Power Consumption', fontsize=14)

# Hide unused subplots if any
for j in range(num_versions, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle('Comparison of Simulated HW Traces (Trace 0) for All isw_and Versions', fontsize=18, y=1.02)
plt.tight_layout()
plt.savefig('figures/trace_HW_compare_all_versions_isw_and_v2.pdf', bbox_inches='tight')
plt.show()

# %%
# Plot one trace (trace 0) from each dataset
fig = plt.figure(figsize=(30, 6))
plt.tight_layout()

font = {'weight': 'normal', 'size': 18}
plt.xlabel('Instruction Sequence', fontdict=font)
plt.ylabel('Simulated Power Consumption', fontdict=font)
plt.yticks(fontsize=14)

colors = ['blue', 'green', 'red']

# Plot each trace
for i, traces in enumerate(trace_data_HD):
    trace = traces[0]  # Take the first trace
    instruction_index = list(range(len(trace)))  # Generate correct X axis
    plt.plot(instruction_index, trace, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])

plt.grid(True)
plt.legend(loc='lower right', fontsize=14)
plt.title('Comparison of Simulated HD Traces (Trace 0) for isw_and v0-v2', fontdict=font)
plt.savefig('figures/trace_HD_compare_all_versions_isw_and_v1.pdf', bbox_inches='tight')
plt.show()

# %%
num_versions = len(trace_data_HD)
cols = math.ceil(num_versions / 2)  # Adjust this if you want 3 or 4 per row
rows = 2 if num_versions > 1 else 1

fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows), sharey=True)

# Flatten axes array
axes = axes.flatten() if num_versions > 1 else [axes]

font = {'weight': 'normal', 'size': 16}
colors = ['blue', 'green', 'red']

for i, (traces, ax) in enumerate(zip(trace_data_HD, axes)):
    trace = traces[0]  # Take the first trace
    instruction_index = list(range(len(trace)))  # X-axis
    ax.plot(instruction_index, trace, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])
    ax.set_title(f'isw_and v{i}', fontsize=16)
    ax.set_xlabel('Instruction Sequence', fontsize=14)
    ax.grid(True)
    ax.legend(fontsize=12)

# Set y-label only for the leftmost plots
for i in range(0, len(axes), cols):
    axes[i].set_ylabel('Simulated Power Consumption', fontsize=14)

# Hide unused subplots if any
for j in range(num_versions, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle('Comparison of Simulated HD Traces (Trace 0) for All isw_and Versions', fontsize=18, y=1.02)
plt.tight_layout()
plt.savefig('figures/trace_HD_compare_all_versions_isw_and_v2.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Load Input CSV

# %%
# Load all csv
input_data = [
    pd.read_csv(f"{base_dir}/tv_isw_and.csv")
    for base_dir in base_dirs
]

# %% [markdown]
# # Extract output value (e.g., x12) and compute intermediate model

# %%
def HW(x):
    return bin(x).count('1')

def HD(x, y):
    return bin(x ^ y).count('1')
    
intermediates_list_hw = [
    (df["c0"].apply(lambda x: int(x, 16)) + df["c1"].apply(lambda x: int(x, 16)))
    .apply(HW)
    .to_numpy()[:100]
    for df in input_data
]

intermediates_list_hd = []
for df in input_data:
    # Convert hex strings to integers
    c0_int = df["c0"].apply(lambda x: int(x, 16))
    c1_int = df["c1"].apply(lambda x: int(x, 16))

    # Sum the two registers
    reg_sum = c0_int + c1_int

    # Shift by 1 to get previous value, compute HD with current value
    reg_sum_shifted = reg_sum.shift(1).fillna(0).astype(int)
    reg_sum = reg_sum.astype(int)

    hd_vals = [HD(curr, prev) for curr, prev in zip(reg_sum, reg_sum_shifted)]

    intermediates_list_hd.append(np.array(hd_vals[:100]))

# %% [markdown]
# # Add Gaussian Noise

# %%
def add_noise(traces, snr_db):
    """
    Add Gaussian noise to traces based on the given SNR in dB.
    SNR (Signal-to-Noise Ratio) = signal_power / noise_power
    """
    signal_power = np.mean(traces ** 2)
    snr_linear = 10 ** (snr_db / 10)
    noise_power = signal_power / snr_linear
    noise = np.random.normal(0, np.sqrt(noise_power), traces.shape)
    return traces + noise

# Add noise (e.g., SNR = 5 dB; adjust for more or less noise)
trace_data_HW = [add_noise(traces, snr_db=5) for traces in trace_data_HW]

trace_data_HD = [add_noise(traces, snr_db=5) for traces in trace_data_HD]

# %% [markdown]
# # Normalize traces

# %%
trace_data_HW = [
    (td - td.mean(axis=0)) / td.std(axis=0) for td in trace_data_HW
]

trace_data_HD = [
    (td - td.mean(axis=0)) / td.std(axis=0) for td in trace_data_HD
]

print(trace_data_HW)
# Out:
# [array([[ 0.46159929, -0.32132589, -2.01189742, ..., -0.025505  ,
#         -0.46995425, -1.16607458],
#        [-1.00861862,  0.17662369,  1.09661963, ..., -1.0169063 ,
#         -0.00308513,  0.35406545],
#        [ 1.10688398,  1.46575947,  0.19588961, ..., -0.31074196,
#          1.67134161, -0.13593338],
#        ...,
#        [-0.20446848,  0.51675495, -0.43245319, ..., -1.35031015,
#         -0.25497948, -2.12519609],
#        [-1.86962878, -1.39731935, -0.08803523, ...,  0.13815863,
#         -1.14915101,  0.98139639],
#        [ 0.87349323,  1.0990452 ,  0.163652  , ...,  0.92703806,
#          0.64144611,  1.39879793]]), array([[-0.98594794, -0.37730814, -1.60296437, ...,  0.38443276,
#         -0.41842175,  0.75182325],
#        [-1.90436865, -0.18096426,  1.10404221, ...,  0.13509928,
#         -0.2460942 , -0.18203584],
#        [-2.97081083, -0.03268481,  0.39380078, ...,  0.5609003 ,
#         -0.47775728, -0.15727655],
#        ...,
#        [ 1.30830678,  1.1791926 , -0.08324224, ...,  1.81413154,
#         -0.51527091, -0.09844616],
#        [ 0.0212425 , -1.06794019, -0.39333028, ...,  1.35701309,
#         -0.144413  , -0.76912058],
#        [-0.61355788,  0.35091684, -0.71782272, ...,  1.50821015,
#         -0.21583618,  1.47368805]]), array([[-1.49038601, -0.80098015,  0.18080569, ..., -0.33561089,
#         -1.46869871, -1.49356214],
#        [-0.7153899 , -0.60320922, -0.62768338, ..., -1.60984905,
#          1.6136916 ,  1.3876015 ],
#        [ 1.46375582, -1.39593804,  2.55491052, ...,  1.75589836,
#          0.11356291, -1.06073795],
#        ...,
#        [-0.19123924, -0.697812  ,  0.31223272, ..., -0.48803825,
#         -1.77505825, -0.68327248],
#        [ 0.7510322 , -0.43522331,  0.5077897 , ...,  0.61756861,
#         -1.40431204, -0.65224324],
#        [ 0.05608865, -0.04419795,  0.54806119, ...,  0.5313013 ,
#          0.82384178,  1.08050949]])]

# %% [markdown]
# # Compute correlation

# %%
correlations_list_HW = []

for traces, intermediates in zip(trace_data_HW, intermediates_list_hw):
    print(f"traces shape hw: {traces.shape}, intermediates shape: {intermediates.shape}")

    traces = (traces - traces.mean(axis=0)) / traces.std(axis=0)

    correlations = np.array([
        np.corrcoef(traces[:, t], intermediates)[0, 1]
        for t in range(traces.shape[1])
    ])

    correlations_list_HW.append(correlations)

correlations_list_HD = []

for traces, intermediates in zip(trace_data_HD, intermediates_list_hd):
    print(f"traces shape hd: {traces.shape}, intermediates shape: {intermediates.shape}")

    traces = (traces - traces.mean(axis=0)) / traces.std(axis=0)

    correlations = np.array([
        np.corrcoef(traces[:, t], intermediates)[0, 1]
        for t in range(traces.shape[1])
    ])

    correlations_list_HD.append(correlations)
# Out:
# traces shape hw: (100, 16), intermediates shape: (100,)
# traces shape hw: (100, 22), intermediates shape: (100,)
# traces shape hw: (100, 15), intermediates shape: (100,)
# traces shape hd: (100, 15), intermediates shape: (100,)
# traces shape hd: (100, 21), intermediates shape: (100,)
# traces shape hd: (100, 14), intermediates shape: (100,)

# %%
plt.figure(figsize=(30, 6))

colors = ['blue', 'green', 'red']
for i, corr in enumerate(correlations_list_HW):
    plt.plot(corr, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])

plt.xlabel("Time Sample")
plt.ylabel("Correlation")
plt.title("Correlation-Based Leakage Detection for HW")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('figures/correlation_HW_all_versions_isw_and_v1.pdf', bbox_inches='tight')
plt.show()

# %%
num_versions = len(correlations_list_HW)
cols = math.ceil(num_versions / 2)  # Try to split into 2 rows
rows = 2 if num_versions > 1 else 1

fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows), sharey=True)

# Flatten the axes array for easy iteration
axes = axes.flatten() if num_versions > 1 else [axes]

colors = ['blue', 'green', 'red']

for i, (corr, ax) in enumerate(zip(correlations_list_HW, axes)):
    ax.plot(corr, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])
    ax.set_title(f'isw_and v{i}', fontsize=14)
    ax.set_xlabel("Time Sample", fontsize=12)
    ax.grid(True)
    ax.legend(fontsize=10)

# Set y-label only on leftmost plots
for i in range(0, len(axes), cols):
    axes[i].set_ylabel("Correlation", fontsize=12)

# Hide any unused subplots
for j in range(num_versions, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig('figures/correlation_HW_all_versions_isw_and_v2.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(30, 6))

colors = ['blue', 'green', 'red']
for i, corr in enumerate(correlations_list_HD):
    plt.plot(corr, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])

plt.xlabel("Time Sample")
plt.ylabel("Correlation")
plt.title("Correlation-Based Leakage Detection for HD")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('figures/correlation_HD_all_versions_isw_and_v1.pdf', bbox_inches='tight')
plt.show()

# %%
num_versions = len(correlations_list_HD)
cols = math.ceil(num_versions / 2)  # Try to split into 2 rows
rows = 2 if num_versions > 1 else 1

fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows), sharey=True)

# Flatten the axes array for easy iteration
axes = axes.flatten() if num_versions > 1 else [axes]

colors = ['blue', 'green', 'red']

for i, (corr, ax) in enumerate(zip(correlations_list_HD, axes)):
    ax.plot(corr, label=f'isw_and v{i}', alpha=0.6, color=colors[i % len(colors)])
    ax.set_title(f'isw_and v{i}', fontsize=14)
    ax.set_xlabel("Time Sample", fontsize=12)
    ax.grid(True)
    ax.legend(fontsize=10)

# Set y-label only on leftmost plots
for i in range(0, len(axes), cols):
    axes[i].set_ylabel("Correlation", fontsize=12)

# Hide any unused subplots
for j in range(num_versions, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig('figures/correlation_HD_all_versions_isw_and_v2.pdf', bbox_inches='tight')
plt.show()
